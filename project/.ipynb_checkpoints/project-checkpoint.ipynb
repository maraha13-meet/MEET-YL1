# %%
f = open('protein.csv', 'rb')
reader = csv.reader(f)

rownum = 0
whiteMeat = []
country = []

for row in reader:
    if rownum != 0 and rownum < 25:
        a = row[0]
        c = a.split()
        d = [c[0]]
        e = map(float, c[1:])
        d.extend(e)
        whiteMeat.append(d[2])
        country.append(d[0])
    rownum += 1
    

print whiteMeat
#print country

Newlist = []
for index in whiteMeat :
    Newlist.append(whiteMeat[0 :])
print Newlist

f.close()
# Out:
# [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5]
# [[1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5], [1.4, 14.0, 9.3, 6.0, 11.4, 10.8, 11.6, 4.9, 9.9, 3.0, 12.4, 10.0, 5.1, 13.6, 4.7, 10.2, 3.7, 6.3, 3.4, 7.8, 10.1, 5.7, 4.6, 12.5]]

# %%
import csv

# %%
myfig = plt.figure()
canvas = myfig.add_subplot(111)
canvas.set_title('Protein consumption from White meat in European countries' ,fontstyle='oblique' )
canvas.set_xlabel('Country')
canvas.set_ylabel('White meat')
asf = range(0,24)
canvas.bar(asf, whiteMeat, width = 0.5, facecolor='yellow', linewidth=1.5)
canvas.set_xticks(asf)
canvas.set_xticklabels(country , fontstyle= 'oblique' )
myfig.autofmt_xdate()
myfig.savefig("my_protein_data.png")

# %% [raw]
# - This chart shows the consumption of protein which is taken from White meat in many European countries , and Austria takes the most protein from White meat !!!
